# %% [markdown]
# Abbildung 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.arange(-5, 5, 0.05)
a = np.exp(a)
plt.plot(a)
plt.show();

# %% [markdown]
# Abbildung 2

# %%
def p(x):
    return pow(x, 5) + 3 * pow(x, 4) + 3 * pow(x, 2) + x + 1
b = np.arange(-10, 10, 0.1)
b = p(b)
plt.plot(b)
plt.show();
